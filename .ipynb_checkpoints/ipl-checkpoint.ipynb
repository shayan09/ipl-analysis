# %%
#Importing library
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv(r'D:\Projects\Ipl\Ipl-Kaggle-Dataset-Analysis\deliveries.csv')

# %%
dataset.shape
# Out:
# (150460, 21)

# %%
dataset.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    143022
# dismissal_kind      143022
# fielder             145091
# dtype: int64

# %%
dataset.replace('N/A',np.NaN)
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
#Subsetting the dataset
is_four = dataset['batsman_runs'] == 4

# %%
fours_data = dataset[is_four]

# %%
fours_data.shape
# Out:
# (17033, 21)

# %%
print("Number of boundaries hit in IPL is:",fours_data.shape[0])
# Out:
# Number of boundaries hit in IPL is: 17033

# %%
print(fours_data['batsman'].value_counts().idxmax()," has hit the most number of fours, that is",fours_data['batsman'].value_counts().max())
# Out:
# G Gambhir  has hit the most number of fours, that is 484

# %%
#Subsetting the dataset
is_six = dataset['batsman_runs'] == 6

# %%
six_data = dataset[is_six]

# %%
six_data.shape
# Out:
# (6523, 21)

# %%
print("Number of sixes hit in the IPL is:",six_data.shape[0])
# Out:
# Number of sixes hit in the IPL is: 6523

# %%
print(six_data['batsman'].value_counts().idxmax(), "has hit the most sixes, that is", six_data['batsman'].value_counts().max())
# Out:
# CH Gayle has hit the most sixes, that is 266

# %%
runs = dataset[['batsman', 'batsman_runs']]
runs_scorer = runs.groupby('batsman',as_index=False).agg('sum') #as_index=False avoids losing columnID that is used to group
data = runs_scorer.sort_values(by='batsman_runs', ascending = False)
data = data.head(10)
x = data['batsman'].tolist()
y = data['batsman_runs'].tolist()
plt.gcf().set_size_inches(20, 8)
plt.bar(x, y, color='g')
plt.title('Most runs scored')
plt.show()

# %%
mdata = pd.read_csv(r'D:\Projects\Ipl\Ipl-Kaggle-Dataset-Analysis\matches.csv')
mdata.replace(['Mumbai Indians','Kolkata Knight Riders','Royal Challengers Bangalore','Deccan Chargers','Chennai Super Kings',
                 'Rajasthan Royals','Delhi Daredevils','Gujarat Lions','Kings XI Punjab',
                 'Sunrisers Hyderabad','Rising Pune Supergiants','Kochi Tuskers Kerala','Pune Warriors','Rising Pune Supergiant']
                ,['MI','KKR','RCB','DC','CSK','RR','DD','GL','KXIP','SRH','RPS','KTK','PW','RPS'],inplace=True)

# %%
mdata.shape
# Out:
# (636, 18)

# %%
mdata.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
sub_data = mdata.iloc[:, 4:7]

# %%
sub_data.shape
# Out:
# (636, 3)

# %%
team = sub_data['toss_winner'].value_counts().idxmax()
is_team = (sub_data['team1'] == team) | (sub_data['team2'] == team)
team_match_data = sub_data[is_team]

# %%
matches = team_match_data['toss_winner'].value_counts().sum()
won = team_match_data['toss_winner'].value_counts().max()
percentage = (won/matches)*100

# %%
print(team,"has won",won,"tosses out of",matches,"making it the highest toss wins in the league at "
                                                 "{0:0.2f}".format(percentage),"%")
# Out:
# MI has won 85 tosses out of 157 making it the highest toss wins in the league at 54.14 %

# %%
teams = sub_data['toss_winner'].unique()
print (teams)
# Out:
# ['RCB' 'RPS' 'KKR' 'KXIP' 'SRH' 'MI' 'GL' 'DD' 'CSK' 'RR' 'DC' 'KTK' 'PW']

# %%
percs = []
for team in teams:
    is_team = (sub_data['team1'] == team) | (sub_data['team2'] == team)
    team_match_data = sub_data[is_team]
    matches = team_match_data['toss_winner'].value_counts().sum()
    won = team_match_data['toss_winner'].value_counts().max()
    percentage = (won/matches)*100
    percs.append(won)

# %%
import matplotlib.pyplot as plt
fig = plt.gcf()
fig.set_size_inches(15,7)
plt.bar(teams, percs, color='grey')
plt.title('Toss Wins')
plt.xlabel('Teams')
plt.ylabel('Tosses Won')
plt.show()

# %%
mom_data = mdata['player_of_match']

# %%
print(mom_data.value_counts().idxmax(),'is the most impactful player with',mom_data.value_counts().max(),
      'Man of the Match awards')
# Out:
# CH Gayle is the most impactful player with 18 Man of the Match awards

# %%
players = mom_data.value_counts().head(10).keys().tolist()
values = mom_data.value_counts().head(10).tolist()

# %%
fig = plt.gcf()
fig.set_size_inches(20, 8)
plt.bar(players, values)
plt.ylim(5,20)
plt.title('Man of the Match Awards')
plt.show()

# %%
total_toss = mdata.shape[0]
sub_data = mdata.loc[:, ['toss_winner','winner']]
toss_wins_match = sub_data['toss_winner'] == sub_data['winner']
sub_data = sub_data[toss_wins_match]
wins_tosses = sub_data.shape[0]
percentage = (wins_tosses/total_toss)*100

# %%
labels = 'Yes', 'No'
share = [percentage, 100 - percentage]

plt.pie(share,labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Likelihood of Toss determining Win')
plt.show()

# %%
out_types = ['caught', 'bowled', 'lbw', 'caught and bowled', 'hit wicket', 'stumped']
df = dataset.loc[dataset['dismissal_kind'].isin(out_types)]
sub_data = df.loc[:, ['bowling_team','over','bowler', 'dismissal_kind', 'fielder']]

# %%
wickets = sub_data['bowler'].value_counts().max()
bowler = sub_data['bowler'].value_counts().idxmax()
print(bowler,'took',wickets,'to become the highest IPL wicket taker')
# Out:
# SL Malinga took 154 to become the highest IPL wicket taker

# %%
top5_bowlers = sub_data['bowler'].value_counts().head(5).keys().tolist()
wickets = sub_data['bowler'].value_counts().head(5).tolist()
fig=plt.gcf()
fig.set_size_inches(15, 7)
plt.bar(top5_bowlers, wickets, color='yellow')
plt.title('Top wicket takers')
plt.xlabel('Player')
plt.ylabel('Wickets')
plt.show()

# %% [markdown]
# #### We will now find the most promising players in based on the last 3 seasons

# %%
promise_data = mdata[['season', 'player_of_match']]
addon_data = pdata
is_promising = promise_data['season'] > 2014
pdata = promise_data[is_promising]
pdata = pdata['player_of_match']

# %%
promising_players = pdata.value_counts().head(5).keys().tolist()
values = pdata.value_counts().head(5).tolist()
plt.gcf().set_size_inches(20,8)
plt.bar(promising_players, values, color='m')
plt.title('Most Valuable player')
plt.ylim(0,10)
plt.show()
